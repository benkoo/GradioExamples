# %%
# !pip install ollama
from IPython.display import Image
import ollama
# Out:
# Requirement already satisfied: ollama in /Users/bkoo/miniconda3/envs/langchain_rag/lib/python3.11/site-packages (0.1.7)
# Requirement already satisfied: httpx<0.26.0,>=0.25.2 in /Users/bkoo/miniconda3/envs/langchain_rag/lib/python3.11/site-packages (from ollama) (0.25.2)
# Requirement already satisfied: anyio in /Users/bkoo/miniconda3/envs/langchain_rag/lib/python3.11/site-packages (from httpx<0.26.0,>=0.25.2->ollama) (4.2.0)
# Requirement already satisfied: certifi in /Users/bkoo/miniconda3/envs/langchain_rag/lib/python3.11/site-packages (from httpx<0.26.0,>=0.25.2->ollama) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/bkoo/miniconda3/envs/langchain_rag/lib/python3.11/site-packages (from httpx<0.26.0,>=0.25.2->ollama) (1.0.2)
# Requirement already satisfied: idna in /Users/bkoo/miniconda3/envs/langchain_rag/lib/python3.11/site-packages (from httpx<0.26.0,>=0.25.2->ollama) (3.6)
# Requirement already satisfied: sniffio in /Users/bkoo/miniconda3/envs/langchain_rag/lib/python3.11/site-packages (from httpx<0.26.0,>=0.25.2->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/bkoo/miniconda3/envs/langchain_rag/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.26.0,>=0.25.2->ollama) (0.14.0)

# %%
file_path="/Users/bkoo/Downloads/tower.jpg"

# %%
Image(filename=file_path)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(file_path)
plt.imshow(img)
plt.show()

# %%
stream = ollama.generate(
    model="llava",
    prompt="Please describe what is in the image",
    images=[file_path],
    stream=True
)

for chunk in stream:
    print(chunk['response'], end='')
# Out:
#  The image shows the Eiffel Tower, a famous landmark in Paris, France. It is illuminated at night with its characteristic golden color from the lights within its structure. In the foreground, there are trees with bare branches, suggesting it might be late autumn or winter. There's also a hint of a building to the left and some artificial lighting that casts a warm glow on the Eiffel Tower. The sky is dark, indicating nighttime conditions, and the overall scene conveys a sense of tranquility and romance typically associated with Paris.
